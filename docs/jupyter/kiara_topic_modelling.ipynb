# %%
# install the package by running the command "pip install git+https://github.com/DHARPA-Project/kiara_plugin.topic_modelling"
# in your virtual environment.
# Alternatively, uncomment and run the line below.
# ! pip install git+https://github.com/DHARPA-Project/kiara_plugin.topic_modelling
# Out:
# Running cells with 'tm_2024_05 (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n tm_2024_05 ipykernel --update-deps --force-reinstall'

# %%
from kiara.api import KiaraAPI
kiara = KiaraAPI.instance()

# %% [markdown]
# ## 1. Data onboarding

# %% [markdown]
# Choose one of the two options below (1.1, 1.2 or 1.3) to onboard data.
# Option 1.3 uses example data present in the topic modelling plugin.

# %% [markdown]
# ### 1.1. Get files from zenodo

# %%
! kiara operation explain topic_modelling.create_table_from_zenodo
# Out:
# ╭─ Operation: topic_modelling.create_table_from_zenodo ────────────────────────╮
# │                                                                              │
# │   Documentation   This module retrieves text files from a specified folder   │
# │                   hosted on Zenodo.                                          │
# │                                                                              │
# │                   It takes the DOI and the name of the file as inputs. It    │
# │                   outputs a table with two columns: one for the file names   │
# │                   and the other for the content of these files.              │
# │                                                                              │
# │   Inputs                                                                     │
# │                     field                                                    │
# │                     name        type     descrip…   Required   Default       │
# │                    ──────────────────────────────────────────────────────    │
# │                     doi         string   The        yes        -- no         │
# │                                          Digital               default       │
# │                                          Object                --            │
# │                                          Identif…                            │
# │                                          for the                             │
# │                                          resourc…                            │
# │                     file_name   string   The name   yes        -- no         │
# │                                          of the                default       │
# │                                          file to               --            │
# │                                          be                                  │
# │                                          process…                            │
# │                                                                              │
# │                                                                              │
# │   Outputs                                                                    │
# │                     field name     type    description                       │
# │                    ──────────────────────────────────────────────────────    │
# │                     corpus_table   table   A table with two columns:         │
# │                                            file names and their              │
# │                                            contents.                         │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
create_table_from_zenodo_inputs = {
    "doi": "4596345",
    "file_name": "ChroniclItaly_3.0_original.zip"
}

# %%
create_table_from_zenodo_results = kiara.run_job('topic_modelling.create_table_from_zenodo', inputs=create_table_from_zenodo_inputs, comment= " ")

# %%
corpus_table_zenodo = create_table_from_zenodo_results['corpus_table']

# %%
create_table_from_zenodo_results
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field          value                                                                                                                   │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   corpus_table                                                                                                                           │
# │                    file_name                                  content                                                                    │
# │                   ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────    │
# │                    2012271201_1918-03-30_ed-1_seq-1_ocr.txt   -A Ci                                                                      │
# │                    2012271201_1918-03-16_ed-1_seq-1_ocr.txt   This newspaper has no objection                                            │
# │                    2012271201_1918-02-02_ed-1_seq-1_ocr.txt   4                                                                          │
# │                    2012271201_1918-02-09_ed-1_seq-1_ocr.txt   M                                                                          │
# │                    2012271201_1918-01-05_ed-1_seq-1_ocr.txt   This newspaper has no objection                                            │
# │                    2012271201_1918-03-23_ed-1_seq-1_ocr.txt   This newspaper. has no bjèction                                            │
# │                    2012271201_1918-04-13_ed-1_seq-1_ocr.txt   a !                                                                        │
# │                    2012271201_1918-01-19_ed-1_seq-1_ocr.txt   This newspaper has no objection to filiti? with the Postmasterof Lynn,     │
# │                    2012271201_1918-06-06_ed-1_seq-1_ocr.txt   ANNO XVI                                                                   │
# │                    2012271201_1918-03-09_ed-1_seq-1_ocr.txt   This newspapet, has no objection                                           │
# │                    2012271201_1918-04-06_ed-1_seq-1_ocr.txt   Tfcis iscwspaper has no obectioa                                           │
# │                    2012271201_1917-12-29_ed-1_seq-1_ocr.txt   !                                                                          │
# │                    2012271201_1918-01-12_ed-1_seq-1_ocr.txt   This newspaper has no objection                                            │
# │                    2012271201_1917-11-24_ed-1_seq-1_ocr.txt   This ncwspapcr has no objectlon to filini: with the Postmasterof Lynn,     │
# │                    2012271201_1918-02-23_ed-1_seq-1_ocr.txt   1                                                                          │
# │                    2012271201_1918-01-26_ed-1_seq-1_ocr.txt   This newspaper has no objection                                            │
# │                    ...                                        ...                                                                        │
# │                    ...                                        ...                                                                        │
# │                    sn84020351_1920-09-25_ed-1_seq-1_ocr.txt   A Cesare quel che                                                          │
# │                    sn84020351_1926-11-27_ed-1_seq-1_ocr.txt   I Fatti E                                                                  │
# │                    sn84020351_1921-02-19_ed-1_seq-1_ocr.txt   Il Comitato Generale Italiano                                              │
# │                    sn84020351_1922-11-25_ed-1_seq-1_ocr.txt   ANCORA DI QU1GLEY!                                                         │
# │                    sn84020351_1925-10-03_ed-1_seq-1_ocr.txt   R. L. VOLPE. MGR.                                                          │
# │                    sn84020351_1929-11-09_ed-1_seq-1_ocr.txt   PICCOLE NOTE                                                               │
# │                    sn84020351_1925-06-20_ed-1_seq-1_ocr.txt   P. ALTIERI. Editot                                                         │
# │                    sn84020351_1925-02-21_ed-1_seq-1_ocr.txt   R. L. VOLPE., MGR.                                                         │
# │                    sn84020351_1923-02-24_ed-1_seq-1_ocr.txt   IL CONC                                                                    │
# │                    sn84020351_1921-02-12_ed-1_seq-1_ocr.txt   Published Every Saturday                                                   │
# │                    sn84020351_1925-09-26_ed-1_seq-1_ocr.txt   P. ALTIERI. Editoi                                                         │
# │                    sn84020351_1922-09-02_ed-1_seq-1_ocr.txt   I nuovi venuti, che hanno abilita'                                         │
# │                    sn84020351_1927-10-29_ed-1_seq-1_ocr.txt   epoca ha fatto onore nor                                                   │
# │                    sn84020351_1921-08-27_ed-1_seq-1_ocr.txt   By P. ALTIERI                                                              │
# │                    sn84020351_1922-02-04_ed-1_seq-1_ocr.txt   Published Every Saturday                                                   │
# │                    sn84020351_1922-08-05_ed-1_seq-1_ocr.txt   Sono stato fra i primi in Italia,                                          │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### 1.2. Get files from github

# %%
! kiara operation explain create.table_from_github_files
# Out:
# ╭─ Operation: create.table_from_github_files ──────────────────────────────────╮
# │                                                                              │
# │   Documentation   Onboards text files from a Github repository.              │
# │                                                                              │
# │   Inputs                                                                     │
# │                     field                                                    │
# │                     name        type     descrip…   Required   Default       │
# │                    ──────────────────────────────────────────────────────    │
# │                     download_   string   The        yes        -- no         │
# │                     github_fi            usernam…              default       │
# │                     les__user                                  --            │
# │                     download_   string   The        yes        -- no         │
# │                     github_fi            reposit…              default       │
# │                     les__repo            name.                 --            │
# │                     download_   string   The        no         -- no         │
# │                     github_fi            branch                default       │
# │                     les__bran            (or tag)              --            │
# │                     ch                   name. If                            │
# │                                          not                                 │
# │                                          specifi…                            │
# │                                          the                                 │
# │                                          default                             │
# │                                          branch                              │
# │                                          will be                             │
# │                                          used.                               │
# │                     download_   string   The        no         -- no         │
# │                     github_fi            bundle                default       │
# │                     les__bund            name use              --            │
# │                     le_name              for the                             │
# │                                          downloa…                            │
# │                                          file, if                            │
# │                                          not                                 │
# │                                          provided                            │
# │                                          it will                             │
# │                                          be                                  │
# │                                          autogen…                            │
# │                     download_   string   The sub    no         -- no         │
# │                     github_fi            path to               default       │
# │                     les__sub_            use. If               --            │
# │                     path                 not                                 │
# │                                          specifi…                            │
# │                                          the root                            │
# │                                          of the                              │
# │                                          source                              │
# │                                          folder                              │
# │                                          will be                             │
# │                                          used.                               │
# │                     download_   list     Include    no         -- no         │
# │                     github_fi            files                 default       │
# │                     les__incl            that end              --            │
# │                     ude_files            with one                            │
# │                                          of those                            │
# │                                          tokens.                             │
# │                                          If not                              │
# │                                          specifi…                            │
# │                                          all file                            │
# │                                          extensi…                            │
# │                                          are                                 │
# │                                          include…                            │
# │                     download_   list     Exclude    no         -- no         │
# │                     github_fi            files                 default       │
# │                     les__excl            that end              --            │
# │                     ude_files            with one                            │
# │                                          of those                            │
# │                                          tokens.                             │
# │                                          If not                              │
# │                                          specifi…                            │
# │                                          no file                             │
# │                                          extensi…                            │
# │                                          are                                 │
# │                                          exclude…                            │
# │                     download_   list     Exclude    no         -- no         │
# │                     github_fi            directo…              default       │
# │                     les__excl            that end              --            │
# │                     ude_dirs             with one                            │
# │                                          of those                            │
# │                                          tokens.                             │
# │                                          If not                              │
# │                                          specifi…                            │
# │                                          no                                  │
# │                                          directo…                            │
# │                                          are                                 │
# │                                          exclude…                            │
# │                                                                              │
# │                                                                              │
# │   Outputs                                                                    │
# │                     field name           type          description           │
# │                    ──────────────────────────────────────────────────────    │
# │                     download_github_fi   file_bundle   The file_bundle       │
# │                     les__file_bundle                   that was              │
# │                                                        onboarded.            │
# │                     create_table_from_   table         The result value      │
# │                     files__table                       (of type              │
# │                                                        'table').             │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
create_table_from_github_files_inputs = {
    "download_github_files__user": "DHARPA-Project",
    "download_github_files__repo": "kiara.examples",
    "download_github_files__sub_path": "kiara.examples-main/examples/workshops/dh_benelux_2023/data",
    "download_github_files__include_files": ["txt"]
}

# %%
create_table_from_github_files_results = kiara.run_job('create.table_from_github_files', inputs=create_table_from_github_files_inputs, comment=" ")

# %%
create_table_from_github_files_results
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                                value                                                                                             │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   create_table_from_files__table                                                                                                         │
# │                                          id     rel_path              mime_type    size    content               file_name               │
# │                                         ─────────────────────────────────────────────────────────────────────────────────────────────    │
# │                                          0      Cronaca_Sovversiva/   text/plain   10428   LI 1,111 """"         2012271201_1903-06-     │
# │                                          1      Cronaca_Sovversiva/   text/plain   11730   Ebdomadario anarchi   2012271201_1903-06-     │
# │                                          2      Cronaca_Sovversiva/   text/plain   11482   ANNO I.               2012271201_1903-06-     │
# │                                          3      Cronaca_Sovversiva/   text/plain   10839   Ebdomadàrio anarchi   2012271201_1903-06-     │
# │                                          4      Cronaca_Sovversiva/   text/plain   11032   NUMERO 5              2012271201_1903-07-     │
# │                                          5      Cronaca_Sovversiva/   text/plain   10648   ANNO I.               2012271201_1903-07-     │
# │                                          6      Cronaca_Sovversiva/   text/plain   10682   ANNO I.               2012271201_1903-08-     │
# │                                          7      Cronaca_Sovversiva/   text/plain   11522   Ciac vtj'y inn        2012271201_1903-08-     │
# │                                          8      Cronaca_Sovversiva/   text/plain   11988   NUMERO 11             2012271201_1903-08-     │
# │                                          9      Cronaca_Sovversiva/   text/plain   11286   Ebdomadario anarchi   2012271201_1903-08-     │
# │                                          10     Cronaca_Sovversiva/   text/plain   10835   SUMERO 13             2012271201_1903-08-     │
# │                                          11     Cronaca_Sovversiva/   text/plain   10750   Ebdomadario anarchi   2012271201_1903-09-     │
# │                                          12     Cronaca_Sovversiva/   text/plain   11003   ANNO I.               2012271201_1903-09-     │
# │                                          13     Cronaca_Sovversiva/   text/plain   11198   ANNO I.               2012271201_1903-09-     │
# │                                          14     Cronaca_Sovversiva/   text/plain   10860   NUMERO 17             2012271201_1903-09-     │
# │                                          15     Cronaca_Sovversiva/   text/plain   10778   li                    2012271201_1903-10-     │
# │                                          ...    ...                   ...          ...     ...                   ...                     │
# │                                          ...    ...                   ...          ...     ...                   ...                     │
# │                                          7244   L'Italia/sn85066408   text/plain   18674   ANNO XXXIII-          sn85066408_1919-12-     │
# │                                          7245   L'Italia/sn85066408   text/plain   19692   anno xxxiii.          sn85066408_1919-12-     │
# │                                          7246   L'Italia/sn85066408   text/plain   24491   ANNO XXXIII           sn85066408_1919-12-     │
# │                                          7247   L'Italia/sn85066408   text/plain   20644   anno xxxiil           sn85066408_1919-12-     │
# │                                          7248   L'Italia/sn85066408   text/plain   19833   anno XXXIII-          sn85066408_1919-12-     │
# │                                          7249   L'Italia/sn85066408   text/plain   19810   anno xxxiii-          sn85066408_1919-12-     │
# │                                          7250   L'Italia/sn85066408   text/plain   15193   FIRST SECTION         sn85066408_1919-12-     │
# │                                          7251   L'Italia/sn85066408   text/plain   19737   ANNO XXXIII           sn85066408_1919-12-     │
# │                                          7252   L'Italia/sn85066408   text/plain   21267   ANNO XXXIII           sn85066408_1919-12-     │
# │                                          7253   L'Italia/sn85066408   text/plain   19738   ANNO XXXIII           sn85066408_1919-12-     │
# │                                          7254   L'Italia/sn85066408   text/plain   23539   ANNO XXXI li-         sn85066408_1919-12-     │
# │                                          7255   L'Italia/sn85066408   text/plain   20528   ANNO XXXIII           sn85066408_1919-12-     │
# │                                          7256   L'Italia/sn85066408   text/plain   19818   PATRIA e umanità*     sn85066408_1919-12-     │
# │                                          7257   L'Italia/sn85066408   text/plain   21006   ANNO XXXIII*          sn85066408_1919-12-     │
# │                                          7258   L'Italia/sn85066408   text/plain   19627   ANNO XXXIII-          sn85066408_1919-12-     │
# │                                          7259   L'Italia/sn85066408   text/plain   23636   \\\ll XXXIII          sn85066408_1919-12-     │
# │                                                                                                                                          │
# │   download_github_files__file_bundle                                                                                                     │
# │                                          File bundle info                                                                                │
# │                                                               bundle name       kiara.examples-main.zip#kiara.examples-main/examp…       │
# │                                                               number_of_files   7260                                                     │
# │                                                               size              160565285                                                │
# │                                                               included files                                                             │
# │                                                                                   (relative) path                          size          │
# │                                                                                  ────────────────────────────────────────────────        │
# │                                                                                   L'Italia/sn85066408_1913-03-10_ed-1_s…   25269         │
# │                                                                                   L'Italia/sn85066408_1910-06-16_ed-1_s…   28506         │
# │                                                                                   L'Italia/sn85066408_1915-05-09_ed-1_s…   18076         │
# │                                                                                   L'Italia/sn85066408_1898-03-22_ed-1_s…   21465         │
# │                                                                                   L'Italia/sn85066408_1911-09-01_ed-1_s…   27931         │
# │                                                                                   L'Italia/sn85066408_1904-11-30_ed-1_s…   20029         │
# │                                                                                   L'Italia/sn85066408_1909-08-17_ed-1_s…   26449         │
# │                                                                                   L'Italia/sn85066408_1912-11-13_ed-1_s…   25568         │
# │                                                                                   L'Italia/sn85066408_1913-12-11_ed-1_s…   23596         │
# │                                                                                   L'Italia/sn85066408_1897-10-14_ed-1_s…   13217         │
# │                                                                                   L'Italia/sn85066408_1909-04-02_ed-1_s…   27463         │
# │                                                                                   L'Italia/sn85066408_1902-06-28_ed-1_s…   18793         │
# │                                                                                   L'Italia/sn85066408_1912-09-28_ed-1_s…   18200         │
# │                                                                                   L'Italia/sn85066408_1903-11-04_ed-1_s…   22460         │
# │                                                                                   L'Italia/sn85066408_1902-12-06_ed-1_s…   18152         │
# │                                                                                   L'Italia/sn85066408_1907-11-19_ed-1_s…   26303         │
# │                                                                                   L'Italia/sn85066408_1919-07-17_ed-1_s…   25978         │
# │                                                                                   L'Italia/sn85066408_1918-04-15_ed-1_s…   16135         │
# │                                                                                   L'Italia/sn85066408_1916-05-20_ed-1_s…   22156         │
# │                                                                                      ... output skipped ...                              │
# │                                                                                      ... output skipped ...                              │
# │                                                                                   Cronaca_Sovversiva/2012271201_1903-10…   10778         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1916-01…   17031         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1909-01…   17823         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1917-03…   15778         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1909-05…   17123         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1912-10…   15179         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1915-04…   17191         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1907-01…   10683         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1906-02…   10351         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1917-07…   13832         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1909-08…   16766         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1907-11…   10020         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1903-11…   12458         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1905-04…   9711          │
# │                                                                                   Cronaca_Sovversiva/2012271201_1909-03…   17393         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1917-08…   15877         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1914-01…   12865         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1908-09…   14381         │
# │                                                                                   Cronaca_Sovversiva/2012271201_1918-03…   21510         │
# │                                                                                                                                          │
# │                                                                                                                                          │
# │                                          Metadata                                                                                        │
# │                                                               download_info   {                                                          │
# │                                                                                 "url":                                                   │
# │                                                                               "https://github.com/DHARPA-Project/kiara.examples/a…       │
# │                                                                                 "response_headers": [                                    │
# │                                                                                   {                                                      │
# │                                                                                     "access-control-allow-origin":                       │
# │                                                                               "https://render.githubusercontent.com",                    │
# │                                                                                     "content-disposition": "attachment;                  │
# │                                                                               filename=kiara.examples-main.zip",                         │
# │                                                                                     "content-security-policy": "default-src              │
# │                                                                               'none'; style-src 'unsafe-inline'; sandbox",               │
# │                                                                                     "content-type": "application/zip",                   │
# │                                                                                     "cross-origin-resource-policy":                      │
# │                                                                               "cross-origin",                                            │
# │                                                                                     "etag":                                              │
# │                                                                               "W/\"5e17d1ad4b4012bfdc84894d4f427aa4ab3962a5960c10…       │
# │                                                                                     "strict-transport-security":                         │
# │                                                                               "max-age=31536000",                                        │
# │                                                                                     "vary":                                              │
# │                                                                               "Authorization,Accept-Encoding,Origin",                    │
# │                                                                                     "x-content-type-options": "nosniff",                 │
# │                                                                                     "x-frame-options": "deny",                           │
# │                                                                                     "x-xss-protection": "1; mode=block",                 │
# │                                                                                     "date": "Mon, 10 Jun 2024 13:06:30 GMT",             │
# │                                                                                     "transfer-encoding": "chunked",                      │
# │                                                                                     "x-github-request-id":                               │
# │                                                                               "A816:1F5371:13EFBA:162D01:6666FA56"                       │
# │                                                                                   },                                                     │
# │                                                                                   {                                                      │
# │                                                                                     "server": "GitHub.com",                              │
# │                                                                                     "date": "Mon, 10 Jun 2024 13:06:30 GMT",             │
# │                                                                                     "content-type": "text/html; charset=utf-8",          │
# │                                                                                     "vary": "X-PJAX, X-PJAX-Container,                   │
# │                                                                               Turbo-Visit, Turbo-Frame, Accept-Encoding, Accept,         │
# │                                                                               X-Requested-With",                                         │
# │                                                                                     "location":                                          │
# │                                                                               "https://codeload.github.com/DHARPA-Project/kiara.e…       │
# │                                                                                     "cache-control": "max-age=0, private",               │
# │                                                                                     "strict-transport-security":                         │
# │                                                                               "max-age=31536000; includeSubdomains; preload",            │
# │                                                                                     "x-frame-options": "deny",                           │
# │                                                                                     "x-content-type-options": "nosniff",                 │
# │                                                                                     "x-xss-protection": "0",                             │
# │                                                                                     "referrer-policy":                                   │
# │                                                                               "no-referrer-when-downgrade",                              │
# │                                                                                     "content-security-policy": "default-src              │
# │                                                                               'none'; base-uri 'self'; child-src                         │
# │                                                                               github.com/assets-cdn/worker/                              │
# │                                                                               gist.github.com/assets-cdn/worker/; connect-src            │
# │                                                                               'self' uploads.github.com www.githubstatus.com             │
# │                                                                               collector.github.com raw.githubusercontent.com             │
# │                                                                               api.github.com github-cloud.s3.amazonaws.com               │
# │                                                                               github-production-repository-file-5c1aeb.s3.amazona…       │
# │                                                                               github-production-upload-manifest-file-7fdce7.s3.am…       │
# │                                                                               github-production-user-asset-6210df.s3.amazonaws.com       │
# │                                                                               api.githubcopilot.com                                      │
# │                                                                               objects-origin.githubusercontent.com                       │
# │                                                                               copilot-proxy.githubusercontent.com/v1/engines/gith…       │
# │                                                                               *.actions.githubusercontent.com                            │
# │                                                                               wss://*.actions.githubusercontent.com                      │
# │                                                                               productionresultssa0.blob.core.windows.net/                │
# │                                                                               productionresultssa1.blob.core.windows.net/                │
# │                                                                               productionresultssa2.blob.core.windows.net/                │
# │                                                                               productionresultssa3.blob.core.windows.net/                │
# │                                                                               productionresultssa4.blob.core.windows.net/                │
# │                                                                               productionresultssa5.blob.core.windows.net/                │
# │                                                                               productionresultssa6.blob.core.windows.net/                │
# │                                                                               productionresultssa7.blob.core.windows.net/                │
# │                                                                               productionresultssa8.blob.core.windows.net/                │
# │                                                                               productionresultssa9.blob.core.windows.net/                │
# │                                                                               productionresultssa10.blob.core.windows.net/               │
# │                                                                               productionresultssa11.blob.core.windows.net/               │
# │                                                                               productionresultssa12.blob.core.windows.net/               │
# │                                                                               productionresultssa13.blob.core.windows.net/               │
# │                                                                               productionresultssa14.blob.core.windows.net/               │
# │                                                                               productionresultssa15.blob.core.windows.net/               │
# │                                                                               productionresultssa16.blob.core.windows.net/               │
# │                                                                               productionresultssa17.blob.core.windows.net/               │
# │                                                                               productionresultssa18.blob.core.windows.net/               │
# │                                                                               productionresultssa19.blob.core.windows.net/               │
# │                                                                               github-production-repository-image-32fea6.s3.amazon…       │
# │                                                                               github-production-release-asset-2e65be.s3.amazonaws…       │
# │                                                                               insights.github.com wss://alive.github.com; font-src       │
# │                                                                               github.githubassets.com; form-action 'self'                │
# │                                                                               github.com gist.github.com                                 │
# │                                                                               copilot-workspace.githubnext.com                           │
# │                                                                               objects-origin.githubusercontent.com;                      │
# │                                                                               frame-ancestors 'none'; frame-src                          │
# │                                                                               viewscreen.githubusercontent.com                           │
# │                                                                               notebooks.githubusercontent.com; img-src 'self'            │
# │                                                                               data: github.githubassets.com                              │
# │                                                                               media.githubusercontent.com                                │
# │                                                                               camo.githubusercontent.com identicons.github.com           │
# │                                                                               avatars.githubusercontent.com                              │
# │                                                                               github-cloud.s3.amazonaws.com                              │
# │                                                                               objects.githubusercontent.com                              │
# │                                                                               secured-user-images.githubusercontent.com/                 │
# │                                                                               user-images.githubusercontent.com/                         │
# │                                                                               private-user-images.githubusercontent.com                  │
# │                                                                               opengraph.githubassets.com                                 │
# │                                                                               github-production-user-asset-6210df.s3.amazonaws.com       │
# │                                                                               customer-stories-feed.github.com                           │
# │                                                                               spotlights-feed.github.com                                 │
# │                                                                               objects-origin.githubusercontent.com                       │
# │                                                                               *.githubusercontent.com; manifest-src 'self';              │
# │                                                                               media-src github.com                                       │
# │                                                                               user-images.githubusercontent.com/                         │
# │                                                                               secured-user-images.githubusercontent.com/                 │
# │                                                                               private-user-images.githubusercontent.com                  │
# │                                                                               github-production-user-asset-6210df.s3.amazonaws.com       │
# │                                                                               gist.github.com; script-src github.githubassets.com;       │
# │                                                                               style-src 'unsafe-inline' github.githubassets.com;         │
# │                                                                               upgrade-insecure-requests; worker-src                      │
# │                                                                               github.com/assets-cdn/worker/                              │
# │                                                                               gist.github.com/assets-cdn/worker/",                       │
# │                                                                                     "content-length": "0",                               │
# │                                                                                     "x-github-request-id":                               │
# │                                                                               "A88F:12F7C3:50FC10D:5291B4F:6666FA56"                     │
# │                                                                                   }                                                      │
# │                                                                                 ],                                                       │
# │                                                                                 "request_time":                                          │
# │                                                                               "2024-06-10T15:06:30.284420+02:00",                        │
# │                                                                                 "download_time_in_seconds": 9.760954                     │
# │                                                                               }                                                          │
# │                                                                                                                                          │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
dl_file_bundle_gh = create_table_from_github_files_results['download_github_files__file_bundle']

# %% [markdown]
# ### 1.3 Get table from local files

# %%
! kiara operation explain import.table.from.local_folder_path
# Out:
# ╭─ Operation: import.table.from.local_folder_path ─────────────────────────────╮
# │                                                                              │
# │   Documentation   Import a table from a local folder containing text         │
# │                   files.                                                     │
# │                                                                              │
# │   Inputs                                                                     │
# │                     field                                                    │
# │                     name        type     descrip…   Required   Default       │
# │                    ──────────────────────────────────────────────────────    │
# │                     path        string   The        yes        -- no         │
# │                                          local                 default       │
# │                                          path of               --            │
# │                                          the                                 │
# │                                          folder                              │
# │                                          to                                  │
# │                                          import.                             │
# │                                                                              │
# │                                                                              │
# │   Outputs                                                                    │
# │                     field name           type          description           │
# │                    ──────────────────────────────────────────────────────    │
# │                     imported_file_bund   file_bundle   The imported file     │
# │                     le                                 bundle.               │
# │                     table                table         The result value      │
# │                                                        (of type              │
# │                                                        'table').             │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
# replace path with your local path to the data folder
import_table_from_local_folder_inputs = {
    "path": "/Users/mariella.decrouychan/Documents/GitHub/kiara_plugin.topic_modelling/tests/resources/data/text_corpus/data"
}

# %%
import_table_from_local_folder_results = kiara.run_job('import.table.from.local_folder_path', inputs=import_table_from_local_folder_inputs, comment=" ")

# %%
import_table_from_local_folder_results
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                  value                                                                                                           │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   imported_file_bundle                                                                                                                   │
# │                            File bundle info                                                                                              │
# │                                                 bundle name       data                                                                   │
# │                                                 number_of_files   16                                                                     │
# │                                                 size              298452                                                                 │
# │                                                 included files                                                                           │
# │                                                                     (relative) path                                        size          │
# │                                                                    ──────────────────────────────────────────────────────────────        │
# │                                                                     La_Rassegna/sn84037025_1917-04-14_ed-1_seq-1_ocr.txt   20647         │
# │                                                                     La_Rassegna/sn84037025_1917-04-07_ed-1_seq-1_ocr.txt   19397         │
# │                                                                     La_Rassegna/sn84037025_1917-04-14_ed-2_seq-1_ocr.txt   20650         │
# │                                                                     La_Rassegna/sn84037025_1917-04-21_ed-1_seq-1_ocr.txt   21017         │
# │                                                                     La_Rassegna/sn84037025_1917-04-21_ed-2_seq-1_ocr.txt   20982         │
# │                                                                     La_Ragione/sn84037024_1917-05-05_ed-2_seq-1_ocr.txt    18474         │
# │                                                                     La_Ragione/sn84037024_1917-05-16_ed-1_seq-1_ocr.txt    18620         │
# │                                                                     La_Ragione/sn84037024_1917-05-16_ed-2_seq-1_ocr.txt    18698         │
# │                                                                     La_Ragione/sn84037024_1917-05-05_ed-1_seq-1_ocr.txt    18346         │
# │                                                                     La_Ragione/sn84037024_1917-04-25_ed-4_seq-1_ocr.txt    16235         │
# │                                                                     La_Ragione/sn84037024_1917-04-25_ed-3_seq-1_ocr.txt    16793         │
# │                                                                     La_Ragione/sn84037024_1917-04-25_ed-2_seq-1_ocr.txt    16679         │
# │                                                                     La_Ragione/sn84037024_1917-04-25_ed-1_seq-1_ocr.txt    16613         │
# │                                                                     La_Ragione/sn84037024_1917-05-16_ed-3_seq-1_ocr.txt    18540         │
# │                                                                     La_Ragione/sn84037024_1917-05-05_ed-4_seq-1_ocr.txt    18481         │
# │                                                                     La_Ragione/sn84037024_1917-05-05_ed-3_seq-1_ocr.txt    18280         │
# │                                                                                                                                          │
# │                                                                                                                                          │
# │                                                                                                                                          │
# │   table                                                                                                                                  │
# │                            id   rel_path                   mime_type    size    content                    file_name                     │
# │                           ───────────────────────────────────────────────────────────────────────────────────────────────────────────    │
# │                            0    La_Ragione/sn84037024_19   text/plain   16613   LA RAGIONE                 sn84037024_1917-04-25_ed-     │
# │                            1    La_Ragione/sn84037024_19   text/plain   16679   LA RAG ONE                 sn84037024_1917-04-25_ed-     │
# │                            2    La_Ragione/sn84037024_19   text/plain   16793   LA RAGIONE                 sn84037024_1917-04-25_ed-     │
# │                            3    La_Ragione/sn84037024_19   text/plain   16235   contro i vili, i camorri   sn84037024_1917-04-25_ed-     │
# │                            4    La_Ragione/sn84037024_19   text/plain   18346   contro i vili, i camorri   sn84037024_1917-05-05_ed-     │
# │                            5    La_Ragione/sn84037024_19   text/plain   18474   LA RAGIONA                 sn84037024_1917-05-05_ed-     │
# │                            6    La_Ragione/sn84037024_19   text/plain   18280   LA RAGIONE                 sn84037024_1917-05-05_ed-     │
# │                            7    La_Ragione/sn84037024_19   text/plain   18481   LA RAGIONE                 sn84037024_1917-05-05_ed-     │
# │                            8    La_Ragione/sn84037024_19   text/plain   18620   contro i vili, i camorri   sn84037024_1917-05-16_ed-     │
# │                            9    La_Ragione/sn84037024_19   text/plain   18698   LA RAG ONE                 sn84037024_1917-05-16_ed-     │
# │                            10   La_Ragione/sn84037024_19   text/plain   18540   contro 1 vili, i camorri   sn84037024_1917-05-16_ed-     │
# │                            11   La_Rassegna/sn84037025_1   text/plain   19397   ■■■                        sn84037025_1917-04-07_ed-     │
# │                            12   La_Rassegna/sn84037025_1   text/plain   20647   La Rassegna                sn84037025_1917-04-14_ed-     │
# │                            13   La_Rassegna/sn84037025_1   text/plain   20650   Both Phones                sn84037025_1917-04-14_ed-     │
# │                            14   La_Rassegna/sn84037025_1   text/plain   21017   ■ jSrìt** W?? iIK 38®f-    sn84037025_1917-04-21_ed-     │
# │                            15   La_Rassegna/sn84037025_1   text/plain   20982   ■Both Phones               sn84037025_1917-04-21_ed-     │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## 2. Tokenize corpus

# %%
! kiara operation explain topic_modelling.tokenize_array
# Out:
# ╭─ Operation: topic_modelling.tokenize_array ──────────────────────────────────╮
# │                                                                              │
# │   Documentation   This module creates tokens from an array or from a         │
# │                   table.                                                     │
# │                                                                              │
# │                   It returns a table containing the initial array or         │
# │                   table, and the tokens as a new column. It is possible to   │
# │                   tokenize by word or by character. If not specified,        │
# │                   tokenization is done by word.                              │
# │                                                                              │
# │                   Dependencies:                                              │
# │                                                                              │
# │                    • NLTK: https://www.nltk.org/                             │
# │                                                                              │
# │   Inputs                                                                     │
# │                     field                                                    │
# │                     name       type      descrip…   Required   Default       │
# │                    ──────────────────────────────────────────────────────    │
# │                     corpus_a   array     Array      yes        -- no         │
# │                     rray                 that                  default       │
# │                                          contains              --            │
# │                                          the text                            │
# │                                          to                                  │
# │                                          tokeniz…                            │
# │                     tokenize   boolean   Tokeniz…   no         False         │
# │                     _by_char                                                 │
# │                     acter                                                    │
# │                                                                              │
# │                                                                              │
# │   Outputs                                                                    │
# │                     field name     type    description                       │
# │                    ──────────────────────────────────────────────────────    │
# │                     tokens_array   array   The tokenized array.              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# We start by getting an array from the table that contains the content to tokenize.

# %%
! kiara operation explain table.pick.column
# Out:
# ╭─ Operation: table.pick.column ───────────────────────────────────────────────╮
# │                                                                              │
# │   Documentation   Pick one column from a table, returning an array.          │
# │                                                                              │
# │   Inputs                                                                     │
# │                     field                                                    │
# │                     name        type     descript…   Required   Default      │
# │                    ──────────────────────────────────────────────────────    │
# │                     table       table    A table.    yes        -- no        │
# │                                                                 default      │
# │                                                                 --           │
# │                     column_na   string   The name    yes        -- no        │
# │                     me                   of the                 default      │
# │                                          column to              --           │
# │                                          extract.                            │
# │                                                                              │
# │                                                                              │
# │   Outputs                                                                    │
# │                     field name   type    description                         │
# │                    ──────────────────────────────────────────────────────    │
# │                     array        array   The column.                         │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
pick_column_inputs = {
    "table": create_table_from_bundle_results['table'],
    "column_name": "content"   
}

# %%
pick_column_results = kiara.run_job('table.pick.column', inputs=pick_column_inputs, comment = " ")

# %% [markdown]
# We can now use the array as input for the tokenize_array operation.

# %%
tokenize_array_inputs = {
    "corpus_array": pick_column_results['array'],
    "column_name": "content"   
}

# %%
tokenize_array_results = kiara.run_job('topic_modelling.tokenize_array', inputs=tokenize_array_inputs, comment= " ")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mariella.decrouychan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tokenize_array_results
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field          value                                                                                                                   │
# │  ─────────────────────────────────────────────────────────────────────────────────────────────────────────                               │
# │   tokens_array                                                                                                                           │
# │                    ['LI', '1,111', '``', "''", "''", "''", '?', '$', ':', 'NUMERO', '1.', 'li', '!' ...                                  │
# │                    ['Ebdomadario', 'anarchico', 'di', 'propaganda', 'rivoluzionaria', '.', 'XJt', ' ...                                  │
# │                    ['ANNO', 'I.', 'NUMERO', '31', 'VVER', 'Ebdomadario', 'anarchico', 'di', 'propag ...                                  │
# │                    ['Ebdomadàrio', 'anarchico', 'di', 'propaganda', 'rivoluzionaria', '.', 'Ut', 'r ...                                  │
# │                    ['NUMERO', '5', 'Ebdomadario', 'anarchico', 'di', 'propaganda', 'rivoluzionaria' ...                                  │
# │                    ['ANNO', 'I.', 'KtJ', 'SIERO', '8', 'Ebdomadario', 'anarchico', 'di', 'propagand ...                                  │
# │                    ['ANNO', 'I.', 'NUMEHO', '9', 'Ebdomadario', 'anarchico', 'di', 'propaganda', 'r ...                                  │
# │                    ['Ciac', 'vtj', "'", 'y', 'inn', 'NUMERO', '10', 'Ebdomadario', 'anarchico', 'di ...                                  │
# │                    ['NUMERO', '11', 'Ebdomadario', 'anarchico', 'di', 'propaganda', 'rivoluzionaria ...                                  │
# │                    ['Ebdomadario', 'anarchico', 'di', 'propaganda', ':', 'rivoluzionaria', '.', 'Ut ...                                  │
# │                    ['SUMERO', '13', 'Ebdomadario', 'anarchico', 'di', 'propaganda', 'rivoluzionaria ...                                  │
# │                    ['Ebdomadario', 'anarchico', 'di', 'propaganda', 'rh', '.', "'-'-", "'", '--', " ...                                  │
# │                    ['ANNO', 'I.', 'NUMERO', '15', '-', 'Ebdomadario', 'anarchico', 'di', 'propagand ...                                  │
# │                    ['ANNO', 'I.', 'NtLNJEKO', '16', 'SOVVERSIVA', 'Ebdomadario', 'anarchico', 'di', ...                                  │
# │                    ['NUMERO', '17', 'Ebdomadario', 'anarchico', 'di', 'propaganda', 'rivoluzionaria ...                                  │
# │                    ['li', 'ANNO', 'I.', 'NUMERO', '1S', '....', '.', 'Ebdomadario', 'anarchico', 'd ...                                  │
# │                    ...                                                                                                                   │
# │                    ...                                                                                                                   │
# │                    ['ANNO', 'XXXIII-', '«', 'PATRIA', 'E', 'UMANITÀ', '’', 'li', 'Piu', '*', 'Vecch ...                                  │
# │                    ['anno', 'xxxiii', '.', 'PATRIA', 'E', "UMANITÀ'", 'Il', 'Piu', '’', 'Vecchio',  ...                                  │
# │                    ['ANNO', 'XXXIII', 'PATRIA', 'E', 'UMANITÀ', '’', 'Il', 'Piu', '*', 'Vecchio', ' ...                                  │
# │                    ['anno', 'xxxiil', 'PATRIA', 'E', "UMANITÀ'", 'Il', 'Phi', '*', 'Vecchio', 'e',  ...                                  │
# │                    ['anno', 'XXXIII-', 'PATRIA', 'E', 'UMANITÀ', '’', 'Il', 'Piu', '’', 'Vecchio',  ...                                  │
# │                    ['anno', 'xxxiii-', 'PATRIA', 'E', 'UMANITÀ', '’', 'Il', 'Piu', '’', 'Vecchio',  ...                                  │
# │                    ['FIRST', 'SECTION', 'anno', 'XXXIII-', 'PATRIA', 'E', 'UMANITÀ', '’', 'Il', 'Pi ...                                  │
# │                    ['ANNO', 'XXXIII', 'PATRIA', 'E', 'UMANITÀ', '»', 'Il', 'Piu', '*', 'Vecchio', ' ...                                  │
# │                    ['ANNO', 'XXXIII', 'PATRIA', 'E', 'UMANITÀ', '’', 'Il', 'Piu', '’', 'Vecchio', ' ...                                  │
# │                    ['ANNO', 'XXXIII', 'PATRIA', 'E', 'UMANITÀ', '’', 'Il', 'Piu', '’', 'Vecchio', ' ...                                  │
# │                    ['ANNO', 'XXXI', 'li-', 'PATRIA', 'E', 'UMANITÀ', '’', 'Il', 'Piu', '*', 'Vecchi ...                                  │
# │                    ['ANNO', 'XXXIII', 'PATRIA', 'E', 'UMANITÀ', '’', 'li', 'PUT', 'Vecchio', 'e', ' ...                                  │
# │                    ['PATRIA', 'e', 'umanità', '*', 'il', 'Piu', '’', 'Vecchio', 'e', 'Diffuso', 'Qu ...                                  │
# │                    ['ANNO', 'XXXIII', '*', 'PATRIA', 'E', 'UMANITÀ', '’', 'li', 'Piu', '*', 'Vecchi ...                                  │
# │                    ['ANNO', 'XXXIII-', 'PATRIA', 'E', 'UMANITÀ', '’', 'Il', 'Piu', '’', 'Vecchio',  ...                                  │
# │                    ['\\\\\\ll', 'XXXIII', 'PATRIA', 'E', 'UMANITÀ', '’', 'Il', 'Piu', '’', 'Vecchio ...                                  │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
